# %% [markdown]
# # 1. Triển khai multiple Source trong TrAdaboost R2

# %%
# coding: UTF-8
import keras
import tensorflow as tf
import numpy as np
import copy
from sklearn.tree import DecisionTreeRegressor

# %%
# =============================================================================
# Public estimators
# =============================================================================


def AdaBoost_R2_T(trans_S, response_S, test, weight, frozen_N, N=20):

    trans_data = copy.deepcopy(trans_S)
    trans_response = copy.deepcopy(response_S)

    row_S = trans_S.shape[0]
    row_T = test.shape[0]

    test_data = np.concatenate((trans_data, test), axis=0)
    weights = copy.deepcopy(weight)
    # initilize data weights
    _weights = weights / sum(weights)

    # Save prediction responses and bata_t
    bata_T = np.zeros(N)
    result_response = np.ones([row_S + row_T, N])

    # Save the prediction responses of test data
    predict = np.zeros(row_T)

    trans_data = np.asarray(trans_data, order='C')
    trans_response = np.asarray(trans_response, order='C')
    test_data = np.asarray(test_data, order='C')

    Total_S_weight = np.sum(weights[-frozen_N:])
    for i in range(N):
        _weights = calculate_P(_weights, frozen_N, Total_S_weight)
        print("+"*60)
        print(train_reg(
            trans_data, trans_response, test_data, _weights).shape)
        result_response[:, i] = train_reg(
            trans_data, trans_response, test_data, _weights).ravel()
        error_rate = calculate_error_rate(
            response_S, result_response[0: row_S, i], _weights)
        if error_rate > 0.5 or error_rate <= 1e-10:
            break

        bata_T[i] = error_rate / (1 - error_rate)

        # Changing the data weights of unfrozen training data
        D_t = np.abs(result_response[frozen_N:row_S,
                     i] - response_S[frozen_N:row_S]).max()
        for j in range(row_S - frozen_N):
            _weights[frozen_N + j] = _weights[frozen_N + j] * np.power(
                bata_T[i], (1-np.abs(result_response[frozen_N + j, i] - response_S[frozen_N+j])/D_t))

    Cal_res = result_response[row_S:, :]
    # Sort the predictions
    sorted_idx = np.argsort(Cal_res, axis=1)

    # Find index of median prediction for each sample
    weight_cdf = np.cumsum(bata_T[sorted_idx], axis=1)
    # return True - False
    median_or_above = weight_cdf >= 0.5 * weight_cdf[:, -1][:, np.newaxis]
    median_idx = median_or_above.argmax(axis=1)

    median_estimators = sorted_idx[np.arange(row_T), median_idx]
    for j in range(row_T):
        predict[j] = Cal_res[j, median_estimators[j]]
    return predict


def calculate_P(weights, frozen_N, Total_S_weight):
    total = np.sum(weights[-frozen_N:])
    weights[-frozen_N:] / total * Total_S_weight
    return np.asarray(weights, order='C')


def train_reg(trans_data, trans_response, test_data, weights):
    """
    # weight resampling 
    cdf = np.cumsum(weights)
    cdf_ = cdf / cdf[-1]
    uniform_samples = np.random.random_sample(len(trans_data))
    bootstrap_idx = cdf_.searchsorted(uniform_samples, side='right')
    # searchsorted returns a scalar
    bootstrap_idx = np.array(bootstrap_idx, copy=False)
    reg = DecisionTreeRegressor(max_depth=2,splitter='random',max_features="log2",random_state=0)
    reg.fit(trans_data[bootstrap_idx], trans_response[bootstrap_idx])
    return reg.predict(test_dat)
    """
    # In order to ensure that the results are not random,
    # the weights are adjusted by the built-in method
    # reg = DecisionTreeRegressor(
    #     max_depth=2, splitter='random', max_features="log2", random_state=0)
    # print("_"*60)
    # display(trans_data.shape, trans_response.shape)
    # reg.fit(trans_data, trans_response, sample_weight=weights)
    # return reg.predict(test_data)
    return base_LSTM(trans_data, test_data, trans_response, weights)

def base_LSTM(train, test, response, weight, N=20):
    model = keras.Sequential()
    model.add(keras.layers.LSTM(32, input_shape=(train.shape[1], 1)))
    model.add(keras.layers.Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0], test.shape[1], 1))
    model.fit(train, response, epochs=N, batch_size=1, verbose=2)
    return model.predict(test)


def calculate_error_rate(response_R, response_H, weight):
    total = np.abs(response_R - response_H).max()
    return np.sum(weight[:] * np.abs(response_R - response_H) / total)

# %%
# coding: UTF-8
import copy
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import LeaveOneOut
from sklearn.tree import DecisionTreeRegressor

# =============================================================================
# Public estimators
# =============================================================================


def Two_stage_TrAdaboost_R2(trans_S, Multi_trans_A, response_S, Multi_response_A, test, steps_S, N):
    # prepare trans_A
    trans_A = list(Multi_trans_A.values())[0]
    if len(Multi_trans_A) == 1:
        pass
    else:
        for i in range(len(Multi_trans_A)-1):
            p = i + 1
            trans_A = np.concatenate((trans_A, list(Multi_trans_A.values())[p]), axis=0)
    # prepare response_A
    response_A = list(Multi_response_A.values())[0]
    if len(Multi_response_A) == 1:
        pass 
    else:
        for i in range(len(Multi_response_A)-1):
            p = i + 1
            response_A = np.concatenate((response_A, list(Multi_response_A.values())[p]), axis=0)

    trans_data = np.concatenate((trans_A, trans_S), axis=0)
    trans_response = np.concatenate((response_A, response_S), axis=0)

    row_A = trans_A.shape[0]
    row_S = trans_S.shape[0]

    # Initialize the weights
    weight  = np.ones(row_A+row_S)/(row_A+row_S)
    bata_T = np.zeros(steps_S)
    
    print ('params initial finished.')
    print('='*60)

    # generate a pool of AdaBoost_R2_T
    AdaBoost_pre = []
    model_error = []
    for i in range(steps_S):
        res_ = AdaBoost_R2_T(trans_data, trans_response, test, weight,row_A, N )
        AdaBoost_pre.append(res_)
        LOOCV_MSE = LOOCV_test(trans_data, trans_response,  weight,row_A, N)
        model_error.append(LOOCV_MSE)
        if len(model_error) > 2 and model_error[-1] > model_error[-2]:
            steps_S = i
            break
        # In order to ensure that the results are not random,
        # the weights are adjusted by the built-in method 
        reg = DecisionTreeRegressor(max_depth=2,splitter='random',max_features="log2",random_state=0)
        reg.fit(trans_data, trans_response,sample_weight = weight)
        pre_res = reg.predict(trans_data)
        E_t = calculate_error_rate(trans_response, pre_res, weight)

        bata_T[i] =  E_t / (1 - E_t)

        # Changing the data weights of same-distribution training data
        total_w_S = row_S/(row_A+row_S) + i/(steps_S-1)*(1 - row_S/(row_A+row_S))
        weight[row_A : row_A+row_S] =  (weight[row_A : row_A+row_S] / weight[row_A : row_A+row_S].sum()) * total_w_S
        # Changing the data weights of diff-distribution training data
        beta_t = binary_search(total_w_S,weight,trans_response,pre_res,row_A,beta_t_range = (0.01,1,0.01),tal=0.03)
        if beta_t == None:
            for j in range(row_A):
                weight[j] = weight[j] * np.exp(-bata_T[i] * np.abs(trans_response[j] - pre_res[j]))
            weight[0:row_A] =  weight[0:row_A] * (1-total_w_S) / weight[0:row_A].sum()
        else:
            D_t = np.abs(trans_response[0:row_A] - pre_res[0:row_A]).max()
            for j in range(row_A):
                weight[j] = weight[j] * np.power(beta_t, np.abs(trans_response[j] - pre_res[j])/D_t)
            weight[0:row_A] =  weight[0:row_A] * (1-total_w_S) / weight[0:row_A].sum()

        print('Iter {}-th result :'.format(i))
        print('{} AdaBoost_R2_T model has been instantiated :'.format(len(model_error)), '|| E_t :', E_t )
        print('The LOOCV MSE on TARGET DOMAIN DATA : ',LOOCV_MSE)
        print('The beta_t calculated by binary search is : ',beta_t)
        print('-'*60)
      
    model_error = np.array(model_error)
    min_index = np.random.choice(np.flatnonzero(model_error == model_error.min()))
    print('Two_stage_TrAdaboost_R2 is done')
    print('='*60)
    print('The minimum mean square error :',model_error[min_index])
    print('The prediction responses of test data are :')
    print(AdaBoost_pre[min_index])
    return AdaBoost_pre[min_index]


def LOOCV_test(trans_data, trans_response, weight,row_A, N):
    loo = LeaveOneOut()
    X = np.array(trans_data)
    Y = np.array(trans_response)
    y_pre_loocv = []
    cal = 0
    for train_index, test_index in loo.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, _ = Y[train_index], Y[test_index]
        w_train, _ = weight[train_index], weight[test_index]
        if cal <= row_A-1:
            y_pre = AdaBoost_R2_T(X_train, y_train, X_test, w_train,row_A-1, N )
        else:
            y_pre = AdaBoost_R2_T(X_train, y_train, X_test, w_train,row_A, N )
        y_pre_loocv.append(y_pre[0])
    return mean_squared_error(trans_response[row_A:],y_pre_loocv[row_A:])

def calculate_error_rate(response_R, response_H, weight):
    total = np.abs(response_R - response_H).max()
    return np.sum(weight[:] * np.abs(response_R - response_H) / total)

# binary_search strategy
def binary_search(total_w_S,__weight,trans_response,pre_res,row_A,beta_t_range = (0.01,1,0.01),tal=0.03):
    # beta_t_range is the search range of beta_t, default = (0.01,1,0.01)
    # viz., beta_t is searched in the interval of 0 to 1, with the step of 0.01 by binary_search
    
    D_t = np.abs(trans_response[0:row_A] - pre_res[0:row_A]).max()
    _list = np.arange(beta_t_range[0],beta_t_range[1],beta_t_range[2])
    low = 0          
    high = len(_list)-1
    while low <= high:   
        weight = copy.deepcopy(__weight) 
        mid = int(np.floor((low+high)/2))
        guess = _list[mid]
        # test beta_t
        for j in range(row_A):
            weight[j] = weight[j] * np.power(guess, np.abs(trans_response[j] - pre_res[j])/D_t)
        diff = (1-total_w_S) -  weight[0:row_A].sum()
        if abs(diff) <= tal:     
            return guess
        # exceed the convergence crtiterion
        elif diff > 0:
            low = mid + 1   
        else:  
            high = mid -1               
      
    print("UNABLE TO COVERGEE IN BINARY SEARCHING")
    return None

# %%
import pandas as pd
Domain_0 = pd.read_csv('C:/Users/acer/OneDrive - Nuce/Desktop/HỌC/ML/Transfer Learning/Paper/Data/Domain0.csv')
Domain_1 = pd.read_csv('C:/Users/acer/OneDrive - Nuce/Desktop/HỌC/ML/Transfer Learning/Paper/Data/Domain1.csv')
Domain_2 = pd.read_csv('C:/Users/acer/OneDrive - Nuce/Desktop/HỌC/ML/Transfer Learning/Paper/Data/Domain2.csv')
Domain_3 = pd.read_csv('C:/Users/acer/OneDrive - Nuce/Desktop/HỌC/ML/Transfer Learning/Paper/Data/Domain3.csv')
Domain_Target = pd.read_csv('C:/Users/acer/OneDrive - Nuce/Desktop/HỌC/ML/Transfer Learning/Paper/Data/Domain5.csv')

# %%
Multi_trans_A = {
    'trans_A_1':Domain_0.iloc[:,:-1],
    'trans_A_2':Domain_1.iloc[:,:-1],
    'trans_A_3':Domain_2.iloc[:,:-1],
    'trans_A_4':Domain_3.iloc[:,:-1]
}
Multi_response_A = {
    'response_A_1':Domain_0.iloc[:,:-1],
    'response_A_2':Domain_1.iloc[:,:-1],
    'response_A_3':Domain_2.iloc[:,:-1],
    'response_A_4':Domain_3.iloc[:,:-1]
}
trans_S = Domain_Target[:4].iloc[:,:-1]
response_S = Domain_Target[:4]. iloc[:,-1:]
test = Domain_Target[4:].iloc[:,:-1]
steps_S = 3
N = 10

# %%
display(response_S, trans_S)
# Out:
#           1
# 0  0.325699
# 1  0.344934
# 2  0.792876
# 3  0.262028
#           0
# 0  0.514219
# 1  1.000000
# 2  0.433249
# 3  0.184482

# %%
Two_stage_TrAdaboost_R2(trans_S, Multi_trans_A, response_S, Multi_response_A, test, steps_S,N)
# Out:
# params initial finished.
# ============================================================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 44/44 - 2s - loss: 0.2541 - 2s/epoch - 52ms/step
# Epoch 2/20
# 44/44 - 0s - loss: 0.1196 - 106ms/epoch - 2ms/step
# Epoch 3/20
# 44/44 - 0s - loss: 0.0453 - 98ms/epoch - 2ms/step
# Epoch 4/20
# 44/44 - 0s - loss: 0.0264 - 98ms/epoch - 2ms/step
# Epoch 5/20
# 44/44 - 0s - loss: 0.0251 - 100ms/epoch - 2ms/step
# Epoch 6/20
# 44/44 - 0s - loss: 0.0237 - 102ms/epoch - 2ms/step
# Epoch 7/20
# 44/44 - 0s - loss: 0.0234 - 98ms/epoch - 2ms/step
# Epoch 8/20
# 44/44 - 0s - loss: 0.0218 - 102ms/epoch - 2ms/step
# Epoch 9/20
# 44/44 - 0s - loss: 0.0211 - 104ms/epoch - 2ms/step
# Epoch 10/20
# 44/44 - 0s - loss: 0.0200 - 105ms/epoch - 2ms/step
# Epoch 11/20
# 44/44 - 0s - loss: 0.0193 - 106ms/epoch - 2ms/step
# Epoch 12/20
# 44/44 - 0s - loss: 0.0186 - 104ms/epoch - 2ms/step
# Epoch 13/20
# 44/44 - 0s - loss: 0.0180 - 112ms/epoch - 3ms/step
# Epoch 14/20
# 44/44 - 0s - loss: 0.0176 - 103ms/epoch - 2ms/step
# Epoch 15/20
# 44/44 - 0s - loss: 0.0170 - 107ms/epoch - 2ms/step
# Epoch 16/20
# 44/44 - 0s - loss: 0.0165 - 96ms/epoch - 2ms/step
# Epoch 17/20
# 44/44 - 0s - loss: 0.0159 - 91ms/epoch - 2ms/step
# Epoch 18/20
# 44/44 - 0s - loss: 0.0159 - 97ms/epoch - 2ms/step
# Epoch 19/20
# 44/44 - 0s - loss: 0.0154 - 94ms/epoch - 2ms/step
# Epoch 20/20
# 44/44 - 0s - loss: 0.0156 - 97ms/epoch - 2ms/step
# 2/2 [==============================] - 1s 3ms/step
# (60, 1)
# Epoch 1/20
# 44/44 - 3s - loss: 0.2837 - 3s/epoch - 57ms/step
# Epoch 2/20
# 44/44 - 0s - loss: 0.1477 - 117ms/epoch - 3ms/step
# Epoch 3/20
# 44/44 - 0s - loss: 0.0620 - 122ms/epoch - 3ms/step
# Epoch 4/20
# 44/44 - 0s - loss: 0.0332 - 113ms/epoch - 3ms/step
# Epoch 5/20
# 44/44 - 0s - loss: 0.0279 - 107ms/epoch - 2ms/step
# Epoch 6/20
# 44/44 - 0s - loss: 0.0265 - 143ms/epoch - 3ms/step
# Epoch 7/20
# 44/44 - 0s - loss: 0.0254 - 100ms/epoch - 2ms/step
# Epoch 8/20
# 44/44 - 0s - loss: 0.0242 - 91ms/epoch - 2ms/step
# Epoch 9/20
# 44/44 - 0s - loss: 0.0239 - 92ms/epoch - 2ms/step
# Epoch 10/20
# 44/44 - 0s - loss: 0.0226 - 116ms/epoch - 3ms/step
# Epoch 11/20
# 44/44 - 0s - loss: 0.0218 - 123ms/epoch - 3ms/step
# Epoch 12/20
# 44/44 - 0s - loss: 0.0207 - 129ms/epoch - 3ms/step
# Epoch 13/20
# 44/44 - 0s - loss: 0.0196 - 132ms/epoch - 3ms/step
# Epoch 14/20
# 44/44 - 0s - loss: 0.0193 - 179ms/epoch - 4ms/step
# Epoch 15/20
# 44/44 - 0s - loss: 0.0186 - 117ms/epoch - 3ms/step
# Epoch 16/20
# 44/44 - 0s - loss: 0.0176 - 189ms/epoch - 4ms/step
# Epoch 17/20
# 44/44 - 0s - loss: 0.0174 - 105ms/epoch - 2ms/step
# Epoch 18/20
# 44/44 - 0s - loss: 0.0166 - 99ms/epoch - 2ms/step
# Epoch 19/20
# 44/44 - 0s - loss: 0.0160 - 100ms/epoch - 2ms/step
# Epoch 20/20
# 44/44 - 0s - loss: 0.0158 - 113ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2471 - 2s/epoch - 50ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1119 - 97ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0453 - 100ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0270 - 104ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0246 - 115ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0240 - 94ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0232 - 95ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0224 - 94ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0212 - 90ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0207 - 92ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0200 - 93ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0190 - 92ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0189 - 95ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0187 - 95ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0174 - 101ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0171 - 100ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0181 - 97ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0164 - 106ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0158 - 103ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0157 - 94ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 7ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2147 - 2s/epoch - 51ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.0981 - 99ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0402 - 88ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0248 - 89ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0228 - 91ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0222 - 102ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0212 - 94ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0202 - 102ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0197 - 103ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0194 - 100ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0186 - 95ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0178 - 98ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0183 - 101ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0169 - 162ms/epoch - 4ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0163 - 210ms/epoch - 5ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0163 - 131ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0166 - 91ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0157 - 91ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0150 - 96ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0150 - 96ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2973 - 2s/epoch - 39ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1707 - 122ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0833 - 133ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0406 - 142ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0301 - 130ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0284 - 151ms/epoch - 4ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0280 - 210ms/epoch - 5ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0264 - 232ms/epoch - 5ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0249 - 155ms/epoch - 4ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0242 - 168ms/epoch - 4ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0238 - 117ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0219 - 108ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0214 - 107ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0202 - 102ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0199 - 115ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0188 - 128ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0183 - 189ms/epoch - 4ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0177 - 140ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0171 - 188ms/epoch - 4ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0167 - 86ms/epoch - 2ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DF5924DEE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 3s - loss: 0.2281 - 3s/epoch - 59ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1017 - 179ms/epoch - 4ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0412 - 216ms/epoch - 5ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0258 - 134ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0237 - 145ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0226 - 157ms/epoch - 4ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0219 - 181ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0208 - 134ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0202 - 148ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0194 - 140ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0188 - 140ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0182 - 144ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0176 - 159ms/epoch - 4ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0175 - 152ms/epoch - 4ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0178 - 165ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0162 - 144ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0157 - 136ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0156 - 107ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0150 - 110ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0151 - 80ms/epoch - 2ms/step
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DF60B525E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 5ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2458 - 2s/epoch - 44ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1210 - 144ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0503 - 140ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0277 - 141ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0252 - 133ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0240 - 118ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0229 - 129ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0221 - 120ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0226 - 116ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0207 - 135ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0199 - 191ms/epoch - 4ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0189 - 231ms/epoch - 5ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0183 - 140ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0181 - 115ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0174 - 103ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0169 - 92ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0172 - 133ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0162 - 177ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0157 - 170ms/epoch - 4ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0160 - 183ms/epoch - 4ms/step
# 2/2 [==============================] - 1s 5ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2453 - 2s/epoch - 56ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1184 - 171ms/epoch - 4ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0496 - 146ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0285 - 116ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0256 - 123ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0243 - 115ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0236 - 114ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0225 - 121ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0216 - 126ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0206 - 90ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0198 - 142ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0195 - 177ms/epoch - 4ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0186 - 168ms/epoch - 4ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0179 - 177ms/epoch - 4ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0177 - 155ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0168 - 167ms/epoch - 4ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0165 - 110ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0169 - 74ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0162 - 92ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0153 - 82ms/epoch - 2ms/step
# 2/2 [==============================] - 1s 3ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2795 - 2s/epoch - 54ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1493 - 106ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0628 - 104ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0329 - 124ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0270 - 116ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0259 - 146ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0250 - 145ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0241 - 122ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0231 - 127ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0221 - 128ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0211 - 118ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0201 - 124ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0201 - 105ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0191 - 195ms/epoch - 5ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0182 - 166ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0181 - 108ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0174 - 135ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0170 - 172ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0165 - 147ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0161 - 110ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 3ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2236 - 2s/epoch - 42ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1092 - 91ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0431 - 94ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0252 - 89ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0226 - 89ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0218 - 87ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0210 - 83ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0208 - 84ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0196 - 86ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0192 - 88ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0182 - 81ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0179 - 79ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0174 - 90ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0168 - 98ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0165 - 105ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0164 - 89ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0160 - 96ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0158 - 87ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0153 - 86ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0153 - 118ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2340 - 2s/epoch - 51ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1078 - 124ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0421 - 125ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0251 - 98ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0234 - 87ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0222 - 105ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0214 - 136ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0219 - 127ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0202 - 97ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0202 - 196ms/epoch - 5ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0187 - 142ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0188 - 158ms/epoch - 4ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0176 - 111ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0170 - 80ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0173 - 92ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0164 - 131ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0159 - 100ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0157 - 80ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0154 - 91ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0151 - 91ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.3446 - 2s/epoch - 42ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.2038 - 87ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.1002 - 89ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0475 - 89ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0331 - 90ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0298 - 88ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0288 - 85ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0277 - 83ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0269 - 87ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0253 - 90ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0246 - 89ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0236 - 90ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0224 - 86ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0220 - 89ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0207 - 93ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0200 - 91ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0195 - 87ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0184 - 96ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0179 - 99ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0173 - 95ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 3s - loss: 0.2939 - 3s/epoch - 62ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1541 - 101ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0663 - 78ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0349 - 135ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0290 - 149ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0279 - 185ms/epoch - 4ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0265 - 113ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0260 - 86ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0249 - 92ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0237 - 84ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0223 - 88ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0222 - 85ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0209 - 77ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0200 - 89ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0195 - 84ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0184 - 81ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0178 - 84ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0175 - 110ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0168 - 94ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0164 - 82ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.3380 - 2s/epoch - 42ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1968 - 123ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0957 - 120ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0447 - 168ms/epoch - 4ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0322 - 117ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0302 - 97ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0291 - 124ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0274 - 116ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0269 - 153ms/epoch - 4ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0252 - 140ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0243 - 122ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0234 - 118ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0222 - 127ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0215 - 117ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0209 - 116ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0198 - 120ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0197 - 111ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0185 - 131ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0178 - 117ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0176 - 120ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 3s - loss: 0.2029 - 3s/epoch - 60ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.0822 - 132ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0321 - 112ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0228 - 119ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0220 - 140ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0209 - 126ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0202 - 153ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0197 - 158ms/epoch - 4ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0185 - 128ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0183 - 189ms/epoch - 4ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0173 - 86ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0168 - 86ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0163 - 105ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0161 - 86ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0160 - 82ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0153 - 87ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0150 - 102ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0150 - 97ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0148 - 104ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0149 - 86ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2777 - 2s/epoch - 51ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1335 - 81ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0560 - 97ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0305 - 85ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0267 - 89ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0257 - 132ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0248 - 139ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0238 - 131ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0228 - 100ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0218 - 98ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0208 - 98ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0199 - 97ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0197 - 93ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0188 - 168ms/epoch - 4ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0179 - 182ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0177 - 122ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0170 - 91ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0167 - 90ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0163 - 88ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0159 - 99ms/epoch - 2ms/step
# 2/2 [==============================] - 1s 4ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.1987 - 2s/epoch - 53ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.0917 - 89ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0354 - 82ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0226 - 82ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0211 - 86ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0208 - 128ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0199 - 116ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0196 - 118ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0186 - 124ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0181 - 117ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0179 - 107ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0173 - 118ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0171 - 114ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0163 - 138ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0158 - 140ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0160 - 164ms/epoch - 4ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0152 - 136ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0150 - 118ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0150 - 199ms/epoch - 5ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0144 - 112ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 3ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2950 - 2s/epoch - 55ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1592 - 95ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0698 - 110ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0342 - 131ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0289 - 71ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0273 - 123ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0264 - 157ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0250 - 135ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0239 - 137ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0235 - 150ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0223 - 138ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0212 - 144ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0207 - 151ms/epoch - 4ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0198 - 123ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0190 - 125ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0183 - 134ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0186 - 145ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0175 - 160ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0168 - 147ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0165 - 154ms/epoch - 4ms/step
# 2/2 [==============================] - 1s 7ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.3227 - 2s/epoch - 49ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1793 - 89ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0862 - 86ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0428 - 99ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0317 - 95ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0295 - 97ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0285 - 86ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0272 - 106ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0260 - 110ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0248 - 150ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0240 - 188ms/epoch - 4ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0232 - 140ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0223 - 89ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0207 - 76ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0206 - 112ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0194 - 117ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0189 - 112ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0182 - 117ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0177 - 79ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0168 - 112ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 6ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2705 - 2s/epoch - 44ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1391 - 98ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0614 - 149ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0323 - 153ms/epoch - 4ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0269 - 163ms/epoch - 4ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0264 - 83ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0253 - 84ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0235 - 94ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0230 - 82ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0220 - 80ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0210 - 80ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0203 - 91ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0194 - 89ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0190 - 90ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0181 - 90ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0171 - 90ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0177 - 87ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0167 - 88ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0157 - 93ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0158 - 109ms/epoch - 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2540 - 2s/epoch - 50ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1158 - 148ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0478 - 181ms/epoch - 4ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0286 - 124ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0251 - 142ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0239 - 146ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0230 - 115ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0221 - 108ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0215 - 139ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0204 - 91ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0198 - 83ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0196 - 81ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0183 - 84ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0177 - 82ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0173 - 77ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0169 - 83ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0166 - 82ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0161 - 81ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0156 - 78ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0154 - 78ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2430 - 2s/epoch - 43ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1141 - 84ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0447 - 89ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0264 - 91ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0240 - 83ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0229 - 82ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0219 - 82ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0215 - 100ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0205 - 95ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0197 - 137ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0192 - 141ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0187 - 155ms/epoch - 4ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0179 - 80ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0173 - 92ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0168 - 89ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0164 - 90ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0158 - 83ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0162 - 95ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0155 - 88ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0153 - 88ms/epoch - 2ms/step
# 2/2 [==============================] - 1s 5ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2499 - 2s/epoch - 38ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1262 - 79ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0533 - 83ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0291 - 90ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0244 - 79ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0232 - 76ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0226 - 78ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0215 - 84ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0211 - 83ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0204 - 91ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0194 - 85ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0188 - 89ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0185 - 82ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0178 - 85ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0172 - 86ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0170 - 107ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0167 - 93ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0163 - 159ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0158 - 143ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0154 - 148ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2689 - 2s/epoch - 56ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1419 - 102ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0646 - 111ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0343 - 97ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0271 - 119ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0262 - 119ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0247 - 202ms/epoch - 5ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0241 - 194ms/epoch - 5ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0234 - 135ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0222 - 191ms/epoch - 4ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0213 - 112ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0214 - 130ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0197 - 137ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0190 - 128ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0189 - 121ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0190 - 132ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0179 - 117ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0169 - 123ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0170 - 118ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0162 - 109ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2861 - 2s/epoch - 45ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1527 - 106ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0663 - 133ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0346 - 184ms/epoch - 4ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0272 - 87ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0260 - 81ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0249 - 91ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0238 - 115ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0231 - 107ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0224 - 113ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0212 - 157ms/epoch - 4ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0205 - 126ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0200 - 122ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0191 - 127ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0185 - 131ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0185 - 126ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0181 - 122ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0174 - 115ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0166 - 119ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0165 - 106ms/epoch - 2ms/step
# 2/2 [==============================] - 1s 3ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2497 - 2s/epoch - 56ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1218 - 96ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0500 - 88ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0283 - 145ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0254 - 182ms/epoch - 4ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0242 - 156ms/epoch - 4ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0229 - 177ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0219 - 122ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0212 - 98ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0206 - 87ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0200 - 99ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0192 - 82ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0186 - 85ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0177 - 83ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0174 - 108ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0168 - 84ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0167 - 101ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0163 - 97ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0156 - 98ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0156 - 106ms/epoch - 2ms/step
# 2/2 [==============================] - 1s 3ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2855 - 2s/epoch - 54ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1609 - 85ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0744 - 95ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0362 - 102ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0287 - 85ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0267 - 90ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0257 - 85ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0248 - 110ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0246 - 92ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0228 - 129ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0218 - 112ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0219 - 97ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0207 - 114ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0197 - 99ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0189 - 108ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0187 - 131ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0185 - 118ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0171 - 106ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0168 - 116ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0162 - 117ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 6ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2591 - 2s/epoch - 43ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1290 - 103ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0566 - 105ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0298 - 100ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0265 - 95ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0249 - 81ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0243 - 80ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0233 - 87ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0222 - 88ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0212 - 100ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0205 - 106ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0199 - 150ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0191 - 169ms/epoch - 4ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0188 - 140ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0178 - 148ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0174 - 121ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0168 - 134ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0166 - 100ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0160 - 78ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0161 - 96ms/epoch - 2ms/step
# 2/2 [==============================] - 1s 4ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2507 - 2s/epoch - 43ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1275 - 135ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0510 - 139ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0278 - 123ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0249 - 122ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0242 - 117ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0237 - 135ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0221 - 139ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0215 - 148ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0207 - 101ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0205 - 109ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0189 - 111ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0186 - 124ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0183 - 137ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0179 - 180ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0171 - 123ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0163 - 119ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0160 - 174ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0159 - 120ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0154 - 143ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 7ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2646 - 2s/epoch - 43ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1280 - 115ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0507 - 114ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0292 - 152ms/epoch - 4ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0260 - 141ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0251 - 138ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0239 - 94ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0230 - 140ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0222 - 113ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0220 - 106ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0205 - 195ms/epoch - 5ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0198 - 157ms/epoch - 4ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0188 - 151ms/epoch - 4ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0184 - 151ms/epoch - 4ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0177 - 162ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0173 - 180ms/epoch - 4ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0171 - 188ms/epoch - 4ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0163 - 121ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0162 - 212ms/epoch - 5ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0158 - 219ms/epoch - 5ms/step
# 2/2 [==============================] - 1s 6ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2900 - 2s/epoch - 55ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1644 - 121ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0732 - 117ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0342 - 119ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0283 - 207ms/epoch - 5ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0266 - 160ms/epoch - 4ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0256 - 183ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0246 - 138ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0240 - 142ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0226 - 130ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0222 - 113ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0210 - 137ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0203 - 78ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0195 - 81ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0190 - 87ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0185 - 105ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0184 - 202ms/epoch - 5ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0180 - 162ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0169 - 142ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0167 - 139ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 3s - loss: 0.2841 - 3s/epoch - 61ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1557 - 87ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0735 - 87ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0361 - 94ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0283 - 102ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0270 - 104ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0260 - 104ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0246 - 103ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0238 - 108ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0225 - 112ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0220 - 138ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0215 - 134ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0200 - 162ms/epoch - 4ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0198 - 93ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0189 - 100ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0185 - 122ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0178 - 215ms/epoch - 5ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0175 - 150ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0167 - 152ms/epoch - 4ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0166 - 140ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 6ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 4s - loss: 0.2687 - 4s/epoch - 84ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1458 - 126ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0656 - 131ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0319 - 122ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0262 - 127ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0247 - 126ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0238 - 133ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0232 - 136ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0225 - 144ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0215 - 146ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0208 - 162ms/epoch - 4ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0204 - 130ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0193 - 126ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0190 - 127ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0184 - 106ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0179 - 93ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0170 - 87ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0167 - 116ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0161 - 117ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0159 - 188ms/epoch - 4ms/step
# 2/2 [==============================] - 1s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2558 - 2s/epoch - 46ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1265 - 76ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0493 - 80ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0279 - 79ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0252 - 84ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0239 - 84ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0232 - 82ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0224 - 93ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0215 - 84ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0208 - 85ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0207 - 86ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0197 - 92ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0188 - 91ms/epoch - 2ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0180 - 84ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0179 - 84ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0168 - 92ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0166 - 83ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0162 - 87ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0161 - 99ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0158 - 84ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2911 - 2s/epoch - 51ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1587 - 93ms/epoch - 2ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0714 - 110ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0356 - 99ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0290 - 185ms/epoch - 4ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0280 - 202ms/epoch - 5ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0267 - 137ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0252 - 87ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0241 - 77ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0238 - 94ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0231 - 124ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0216 - 114ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0207 - 136ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0204 - 124ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0192 - 115ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0189 - 112ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0183 - 81ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0177 - 98ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0174 - 81ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0167 - 85ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 6ms/step
# (44, 1)
# Epoch 1/20
# ...
# Epoch 15/20
# 43/43 - 0s - loss: 0.0177 - 126ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0173 - 166ms/epoch - 4ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0167 - 101ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0167 - 112ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0163 - 107ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0159 - 141ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2759 - 2s/epoch - 48ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1458 - 142ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0642 - 107ms/epoch - 2ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0333 - 102ms/epoch - 2ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0272 - 97ms/epoch - 2ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0262 - 125ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0253 - 113ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0241 - 102ms/epoch - 2ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0234 - 112ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0223 - 133ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0214 - 110ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0208 - 116ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0201 - 117ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0198 - 150ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0189 - 111ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0184 - 130ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0173 - 125ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0171 - 161ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0167 - 124ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0162 - 146ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 5ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2377 - 2s/epoch - 54ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1147 - 134ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0483 - 121ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0268 - 136ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0236 - 118ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0232 - 132ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0219 - 175ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0211 - 116ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0204 - 144ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0200 - 122ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0192 - 159ms/epoch - 4ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0185 - 114ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0180 - 116ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0173 - 128ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0177 - 152ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0170 - 120ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0163 - 118ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0157 - 116ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0153 - 154ms/epoch - 4ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0153 - 125ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2683 - 2s/epoch - 53ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1391 - 227ms/epoch - 5ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0602 - 157ms/epoch - 4ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0317 - 126ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0266 - 139ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0257 - 133ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0242 - 143ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0233 - 139ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0223 - 164ms/epoch - 4ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0215 - 279ms/epoch - 6ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0212 - 353ms/epoch - 8ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0200 - 379ms/epoch - 9ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0190 - 295ms/epoch - 7ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0185 - 210ms/epoch - 5ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0178 - 155ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0175 - 181ms/epoch - 4ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0171 - 272ms/epoch - 6ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0164 - 188ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0165 - 190ms/epoch - 4ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0162 - 186ms/epoch - 4ms/step
# 2/2 [==============================] - 1s 3ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2614 - 2s/epoch - 44ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1301 - 147ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0530 - 133ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0280 - 174ms/epoch - 4ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0239 - 153ms/epoch - 4ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0228 - 157ms/epoch - 4ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0220 - 151ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0210 - 162ms/epoch - 4ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0206 - 153ms/epoch - 4ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0193 - 156ms/epoch - 4ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0188 - 247ms/epoch - 6ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0183 - 164ms/epoch - 4ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0180 - 136ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0168 - 146ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0170 - 159ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0161 - 147ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0155 - 147ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0152 - 130ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0149 - 156ms/epoch - 4ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0154 - 162ms/epoch - 4ms/step
# 2/2 [==============================] - 1s 5ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 4s - loss: 0.2618 - 4s/epoch - 99ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1291 - 189ms/epoch - 4ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0538 - 165ms/epoch - 4ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0301 - 169ms/epoch - 4ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0258 - 144ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0249 - 149ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0230 - 153ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0221 - 130ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0212 - 122ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0205 - 121ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0195 - 150ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0189 - 341ms/epoch - 8ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0188 - 252ms/epoch - 6ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0177 - 190ms/epoch - 4ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0170 - 179ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0166 - 151ms/epoch - 4ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0159 - 199ms/epoch - 5ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0157 - 130ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0154 - 178ms/epoch - 4ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0151 - 190ms/epoch - 4ms/step
# 2/2 [==============================] - 1s 5ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 3s - loss: 0.2993 - 3s/epoch - 61ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1573 - 119ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0681 - 140ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0329 - 132ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0258 - 146ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0245 - 145ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0229 - 160ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0213 - 164ms/epoch - 4ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0195 - 148ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0183 - 151ms/epoch - 4ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0167 - 152ms/epoch - 4ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0155 - 144ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0143 - 132ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0132 - 151ms/epoch - 4ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0117 - 153ms/epoch - 4ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0109 - 168ms/epoch - 4ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0098 - 156ms/epoch - 4ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0093 - 227ms/epoch - 5ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0083 - 156ms/epoch - 4ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0076 - 139ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 3ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 3s - loss: 0.2798 - 3s/epoch - 79ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1495 - 185ms/epoch - 4ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0676 - 149ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0303 - 258ms/epoch - 6ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0234 - 129ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0219 - 144ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0209 - 164ms/epoch - 4ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0192 - 142ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0176 - 137ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0166 - 91ms/epoch - 2ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0150 - 104ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0138 - 105ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0126 - 121ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0118 - 117ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0105 - 127ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0097 - 161ms/epoch - 4ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0090 - 98ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0080 - 109ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0072 - 95ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0067 - 105ms/epoch - 2ms/step
# 2/2 [==============================] - 1s 5ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2427 - 2s/epoch - 44ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1113 - 135ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0462 - 126ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0265 - 123ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0231 - 137ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0226 - 111ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0214 - 125ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0199 - 120ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0190 - 121ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0184 - 117ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0179 - 110ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0169 - 120ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0158 - 116ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0158 - 121ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0145 - 122ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0143 - 122ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0139 - 126ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0135 - 188ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0126 - 96ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0123 - 109ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 7ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2470 - 2s/epoch - 49ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1235 - 124ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0497 - 118ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0265 - 119ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0235 - 159ms/epoch - 4ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0224 - 87ms/epoch - 2ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0218 - 108ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0213 - 169ms/epoch - 4ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0194 - 161ms/epoch - 4ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0186 - 162ms/epoch - 4ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0181 - 105ms/epoch - 2ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0170 - 95ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0162 - 126ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0153 - 89ms/epoch - 2ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0150 - 111ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0146 - 106ms/epoch - 2ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0140 - 103ms/epoch - 2ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0134 - 99ms/epoch - 2ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0129 - 123ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0128 - 115ms/epoch - 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Epoch 1/20
# 43/43 - 2s - loss: 0.2630 - 2s/epoch - 44ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1301 - 132ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0524 - 120ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0289 - 118ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0257 - 219ms/epoch - 5ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0246 - 108ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0237 - 94ms/epoch - 2ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0229 - 108ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0223 - 102ms/epoch - 2ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0213 - 114ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0205 - 110ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0206 - 107ms/epoch - 2ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0193 - 115ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0188 - 121ms/epoch - 3ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0182 - 124ms/epoch - 3ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0179 - 129ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0178 - 117ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0169 - 137ms/epoch - 3ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0163 - 99ms/epoch - 2ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0163 - 114ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# (44, 1)
# Epoch 1/20
# 43/43 - 2s - loss: 0.2828 - 2s/epoch - 43ms/step
# Epoch 2/20
# 43/43 - 0s - loss: 0.1510 - 129ms/epoch - 3ms/step
# Epoch 3/20
# 43/43 - 0s - loss: 0.0654 - 128ms/epoch - 3ms/step
# Epoch 4/20
# 43/43 - 0s - loss: 0.0324 - 130ms/epoch - 3ms/step
# Epoch 5/20
# 43/43 - 0s - loss: 0.0267 - 134ms/epoch - 3ms/step
# Epoch 6/20
# 43/43 - 0s - loss: 0.0254 - 131ms/epoch - 3ms/step
# Epoch 7/20
# 43/43 - 0s - loss: 0.0250 - 136ms/epoch - 3ms/step
# Epoch 8/20
# 43/43 - 0s - loss: 0.0244 - 122ms/epoch - 3ms/step
# Epoch 9/20
# 43/43 - 0s - loss: 0.0232 - 131ms/epoch - 3ms/step
# Epoch 10/20
# 43/43 - 0s - loss: 0.0227 - 123ms/epoch - 3ms/step
# Epoch 11/20
# 43/43 - 0s - loss: 0.0211 - 119ms/epoch - 3ms/step
# Epoch 12/20
# 43/43 - 0s - loss: 0.0206 - 132ms/epoch - 3ms/step
# Epoch 13/20
# 43/43 - 0s - loss: 0.0195 - 121ms/epoch - 3ms/step
# Epoch 14/20
# 43/43 - 0s - loss: 0.0192 - 197ms/epoch - 5ms/step
# Epoch 15/20
# 43/43 - 0s - loss: 0.0193 - 102ms/epoch - 2ms/step
# Epoch 16/20
# 43/43 - 0s - loss: 0.0181 - 109ms/epoch - 3ms/step
# Epoch 17/20
# 43/43 - 0s - loss: 0.0178 - 134ms/epoch - 3ms/step
# Epoch 18/20
# 43/43 - 0s - loss: 0.0177 - 181ms/epoch - 4ms/step
# Epoch 19/20
# 43/43 - 0s - loss: 0.0168 - 149ms/epoch - 3ms/step
# Epoch 20/20
# 43/43 - 0s - loss: 0.0163 - 112ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# UNABLE TO COVERGEE IN BINARY SEARCHING
# Iter 2-th result :
# 3 AdaBoost_R2_T model has been instantiated : || E_t : 9.841922889148009
# The LOOCV MSE on TARGET DOMAIN DATA :  0.12013532756257245
# The beta_t calculated by binary search is :  None
# ------------------------------------------------------------
# Two_stage_TrAdaboost_R2 is done
# ============================================================
# The minimum mean square error : 0.11608509905371031
# The prediction responses of test data are :
# [0.48414111 0.27658093 0.39983696 0.21004099 0.63859016 0.23142371
#  0.30727255 0.32318285 0.61331946 0.46409091 0.45541608 0.58039027
#  0.45394582 0.4468078  0.48571655 0.44146907]
# array([0.48414111, 0.27658093, 0.39983696, 0.21004099, 0.63859016,
#        0.23142371, 0.30727255, 0.32318285, 0.61331946, 0.46409091,
#        0.45541608, 0.58039027, 0.45394582, 0.4468078 , 0.48571655,
#        0.44146907])

# %% [markdown]
# vector 3 giá trị, theo dạng time-series
